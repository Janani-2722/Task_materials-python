# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ----------------------------------- ---- 9.7/11.0 MB 52.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 40.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    --------------- ------------------------ 5.0/12.8 MB 24.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 35.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 28.3 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------- ----------------------------- 1/4 [tzdata]
# ...

# %%
# !python -m pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 1.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 1.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 2.0 MB/s  0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.2
#     Uninstalling pip-25.2:
#       Successfully uninstalled pip-25.2
# ...

# %%
import pandas as pd
pd.__version__
# Out:
# '2.3.3'

# %%
df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)

print(df)
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
df["Name"].str.split(",")
# Out:
# 0     [Braund,  Mr. Owen Harris]
# 1    [Allen,  Mr. William Henry]
# 2    [Bonnell,  Miss. Elizabeth]
# Name: Name, dtype: object

# %%
df["Surname"] = df["Name"].str.split(",").str.get(0)
df["Surname"]
# Out:
# 0     Braund
# 1      Allen
# 2    Bonnell
# Name: Surname, dtype: object

# %%
df["Name"].str.contains("Allen")
# Out:
# 0    False
# 1     True
# 2    False
# Name: Name, dtype: bool

# %%
df[df["Name"].str.contains("Allen")]
# Out:
#                        Name  Age   Sex Surname
# 1  Allen, Mr. William Henry   35  male   Allen

# %%
df["Name"].str.len()
# Out:
# 0    23
# 1    24
# 2    24
# Name: Name, dtype: int64

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   38.333333
# std    18.230012
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    46.500000
# max    58.000000

# %%
ages = pd.Series([22, 35, 58], name="Age")
print(ages)
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
data = pd.read_csv("C:\\Users\\XNovaQ.16\\Documents\\Marks.csv", sep = ',') #use double slash or r to clear the unicode error.
data
# Out:
#    MarkID  StudentID    Subject  Marks
# 0       1        101       DBMS     85
# 1       2        101         AI     92
# 2       3        102  Mechanics     78
# 3       4        103       DBMS     88
# 4       5        104   Calculus     90

# %%
data.head(2)
# Out:
#    MarkID  StudentID Subject  Marks
# 0       1        101    DBMS     85
# 1       2        101      AI     92

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MarkID     5 non-null      int64
#  1   StudentID  5 non-null      int64
#  2   Subject    5 non-null      object
#  3   Marks      5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 292.0+ bytes

# %%
type(data['Subject'])
# Out:
# pandas.core.series.Series

# %%
data['Subject'].shape
# Out:
# (5,)

# %%
data.describe()
# Out:
#          MarkID  StudentID      Marks
# count  5.000000    5.00000   5.000000
# mean   3.000000  102.20000  86.600000
# std    1.581139    1.30384   5.458938
# min    1.000000  101.00000  78.000000
# 25%    2.000000  101.00000  85.000000
# 50%    3.000000  102.00000  88.000000
# 75%    4.000000  103.00000  90.000000
# max    5.000000  104.00000  92.000000

# %%
result = data.loc[:,'Subject']
print(result)
# Out:
# 0         DBMS
# 1           AI
# 2    Mechanics
# 3         DBMS
# 4     Calculus
# Name: Subject, dtype: object

# %%
result1 = data.iloc[:2]
print(result1)
# Out:
#    MarkID  StudentID Subject  Marks
# 0       1        101    DBMS     85
# 1       2        101      AI     92

# %%
greater_marks =data[ data['Marks'] > 90]
print(greater_marks)
greater_marks = data['Marks'] > 90
print(greater_marks)
# Out:
#    MarkID  StudentID Subject  Marks
# 1       2        101      AI     92
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: Marks, dtype: bool

# %%
mean_marks = data.groupby('Subject')['Marks'].mean()
print(mean_marks)
# Out:
# Subject
# AI           92.0
# Calculus     90.0
# DBMS         86.5
# Mechanics    78.0
# Name: Marks, dtype: float64

# %%
data1 = pd.read_csv(r"C:\Users\XNovaQ.16\Documents\students.csv", sep = ',')
data1
# Out:
#    StudentID FirstName LastName Gender         DOB  DepartmentID
# 0        101      Arun    Brown      F  2002-03-12             1
# 1        102      Alan    Davis      M  2001-11-05             2
# 2        103     Cabil    Evans      F  2003-06-21             1
# 3        104      Babu   Foster      M  2002-02-02             3

# %%
merged_table = pd.merge(data,data1,on = 'StudentID')
print(merged_table)
# Out:
#    MarkID  StudentID    Subject  Marks FirstName LastName Gender         DOB  \
# 0       1        101       DBMS     85      Arun    Brown      F  2002-03-12
# 1       2        101         AI     92      Arun    Brown      F  2002-03-12
# 2       3        102  Mechanics     78      Alan    Davis      M  2001-11-05
# 3       4        103       DBMS     88     Cabil    Evans      F  2003-06-21
# 4       5        104   Calculus     90      Babu   Foster      M  2002-02-02
#
#    DepartmentID
# 0             1
# 1             1
# 2             2
# 3             1
# 4             3

# %%
renamed_column = data.rename(columns = {'Subject' :'Subjects'})
print(renamed_column)
renamed_into_lower = data.rename(columns = str.lower)
print(renamed_into_lower)
# Out:
#    MarkID  StudentID   Subjects  Marks
# 0       1        101       DBMS     85
# 1       2        101         AI     92
# 2       3        102  Mechanics     78
# 3       4        103       DBMS     88
# 4       5        104   Calculus     90
#    markid  studentid    subject  marks
# 0       1        101       DBMS     85
# 1       2        101         AI     92
# 2       3        102  Mechanics     78
# 3       4        103       DBMS     88
# 4       5        104   Calculus     90

# %%
data["Marks"].mean()
# Out:
# np.float64(86.6)

# %%
data["Marks"].median()
# Out:
# np.float64(88.0)

# %%
data["Marks"].value_counts() #The value_counts() method counts the number of records for each category in a column.
# Out:
# Marks
# 85    1
# 92    1
# 78    1
# 88    1
# 90    1
# Name: count, dtype: int64

# %%
data.groupby('Marks')['Marks'].count() #The function is a shortcut, as it is actually a groupby operation in 
#combination with counting of the number of records within each group
# Out:
# Marks
# 78    1
# 85    1
# 88    1
# 90    1
# 92    1
# Name: Marks, dtype: int64

# %%
data1.sort_values(by = 'DepartmentID').head()
# Out:
#    StudentID FirstName LastName Gender         DOB  DepartmentID
# 0        101      Arun    Brown      F  2002-03-12             1
# 2        103     Cabil    Evans      F  2003-06-21             1
# 1        102      Alan    Davis      M  2001-11-05             2
# 3        104      Babu   Foster      M  2002-02-02             3

# %%
data1.sort_values(by = 'DepartmentID', ascending = False).head()
# Out:
#    StudentID FirstName LastName Gender         DOB  DepartmentID
# 3        104      Babu   Foster      M  2002-02-02             3
# 1        102      Alan    Davis      M  2001-11-05             2
# 0        101      Arun    Brown      F  2002-03-12             1
# 2        103     Cabil    Evans      F  2003-06-21             1

# %%
print(data1['DOB'].max())
print(data1['DOB'].min())
# Out:
# 2003-06-21
# 2001-11-05

# %%
data1['LastName'].str.lower()
# Out:
# 0     brown
# 1     davis
# 2     evans
# 3    foster
# Name: LastName, dtype: object
